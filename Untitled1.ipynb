# %% [markdown]
# # Library

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd
import os
import glob
import numpy as np
import time
import pickle
from statistics import mean

class data_loader:
    '''
    Mainly Go and look at the folder and file list

    '''
    def __init__(self,path,Desired_param=False):
        self.path=path
        self.file_directory=[]
        self.Param=[]
        self.Selected_Param=[]
        self.Param_pd=[]
        self.Par=[]
        self.Desired_param=Desired_param # wanted param such as pressue 1bar and offset 10mm
        self.Desired_file_directory=[] # Directory list based on wanted param
        self.contents=[] # Force or TCP , ANalogue => file set
        self.total_df=[]
        
     ## 1. Searching the folder with different parameter    
    def file_searching(self,path):
        '''
        Input : path
        Output : split the directory name with '_' and make a directionary for this
        '''
        ## 1. Make file list
        file_lists=os.listdir(path)
        for file_list in file_lists:
            #print(file_list)
            # Only extract folder
            if os.path.isdir(os.path.join(path,file_list)): 
                self.file_directory.append(file_list)

        ## 2. Parameter list
        self.Param=[]
        for file in self.file_directory:
            self.Param.append(file.split('_'))
        self.Param_pd=pd.DataFrame(self.Param)

        k=0
        print("1st Folder name : ", self.file_directory[0])
        self.contents=os.listdir(os.path.join(self.path,file_list))
        print("Contents in the folder :", self.contents,"\n\n")
        for i in range(len(self.Param[1])):
            '''if len(self.Param_pd[i].unique())==1:
                print("**Variable**",self.Param_pd[i].unique(),"\n")
                V=self.Param_pd[i].unique()
            else:
                k=k+1
                print(k,"Parameters",self.Param_pd[i].unique(),"\n")
                self.Par.append(self.Param_pd[i].unique())'''
            k=k+1
            print(k,"Parameters",self.Param_pd[i].unique(),"\n")
            self.Par.append(self.Param_pd[i].unique())
    ## 2. Make list of folder with desired parameter and list of parameter        
    def desired_file_path(self,Desired_param):
        if len(self.Par) != len(Desired_param):
            print(f'Your input length ({len(self.Desired_param)}) does not match to Param length ({len(self.Par)})')
        else:
            #print('Go')
            for i in range(len(self.Par)):
                #print(i)
                #print((A.Par[i][input_param[i][:]]))
                if i ==0:
                    filt=self.Param_pd[i].isin(self.Par[i][self.Desired_param[i][:]])
                    #print(filt)
                else:
                    filt_temp=self.Param_pd[i].isin(self.Par[i][self.Desired_param[i][:]])
                    #print(filt_temp)
                    filt=filt_temp&filt
                    #print('print filtered')
                    
                    self.Selected_Param=[self.Param[i] for i in list(self.Param_pd.index[filt])]
                    self.Desired_file_directory=[self.path+'/'+self.file_directory[i] for i in list(self.Param_pd.index[filt])]
    
        return self.Desired_file_directory
    ## 3. Read the file and add the parameters (Kevin code)
        # read the file and add the parameter values
        # append into one value
    def read_Data_pandas(self,Colums,New_Columns):
        for j in range(len(self.Desired_file_directory)):
            
            ################## Should change this part ######################
            with open('vectorset', 'rb') as f:
                data_set = pickle.load(f)
            df = pd.DataFrame(data_set, columns=Columns)
            
                
            ###################3## Until this length####################3
            for i in range(len(New_Columns)):
                if len(New_Columns)==len(self.Selected_Param[0]):
                    df.insert(len(Columns)+i,New_Columns[i],self.Selected_Param[j][i])
                else :
                    print(f'New column name number of {len(New_Columns)}')
            if j ==0:
                self.total_df= df
            else:
                self.total_df=pd.concat([self.total_df,df],ignore_index=True)
        
        return self.total_df
    ## 4. Filtering the wanted data set and desired combination of input
    
    
    ## 6. Save the pickle

# %%
A.Selected_Param
# Out:
# [['P0.7', 'L', 'cen', '1'], ['P1.4', 'L', 'cen', '1']]

# %%
# Out:
#         Force_X   Force_Y   Force_Z  Torque_X  Torque_Y  Torque_Z  \
# 0     -0.001032  0.003147  0.027862  0.000034  0.000008 -0.000392
# 1     -0.001032  0.003147  0.027862  0.000034  0.000008 -0.000392
# 2     -0.001032  0.003147  0.027862  0.000034  0.000008 -0.000392
# 3     -0.001032  0.003147  0.027862  0.000034  0.000008 -0.000392
# 4     -0.001032  0.003147  0.027862  0.000034  0.000008 -0.000392
# ...         ...       ...       ...       ...       ...       ...
# 10309 -0.003196  0.022557  0.039090  0.000388 -0.000059 -0.000344
# 10310 -0.003196  0.022557  0.039090  0.000388 -0.000059 -0.000344
# 10311 -0.003186  0.022070  0.037911  0.000373 -0.000106 -0.000351
# 10312 -0.003186  0.022070  0.037911  0.000373 -0.000106 -0.000351
# 10313 -0.003186  0.022070  0.037911  0.000373 -0.000106 -0.000351
#
#        Sensor_P_1_1  Sensor_P_1_2  Sensor_P_2_1  Sensor_P_2_2  ...  \
# 0               0.0           0.0         3.674         7.520  ...
# 1               0.0           0.0         3.674         7.520  ...
# 2               0.0           0.0         3.674         7.520  ...
# 3               0.0           0.0         3.674         7.520  ...
# 4               0.0           0.0         3.674         7.520  ...
# ...             ...           ...           ...           ...  ...
# 10309           0.0           0.0         3.675         7.521  ...
# 10310           0.0           0.0         3.675         7.521  ...
# 10311           0.0           0.0         3.675         7.521  ...
# 10312           0.0           0.0         3.675         7.521  ...
# 10313           0.0           0.0         3.675         7.521  ...
#
#        Sensor_P_5_2  Sensor_P_6_1  Sensor_P_6_2  Sensor_P_7_1  Sensor_P_7_2  \
# 0             9.118         7.565         8.181        10.200         5.680
# 1             9.124         7.565         8.181        10.200         5.680
# 2             9.124         7.565         8.181        10.200         5.680
# 3             9.124         7.565         8.183        10.198         5.669
# 4             9.124         7.565         8.183        10.198         5.669
# ...             ...           ...           ...           ...           ...
# 10309         9.126         7.563         8.174        10.192         5.672
# 10310         9.126         7.563         8.174        10.192         5.672
# 10311         9.126         7.563         8.174        10.192         5.672
# 10312         9.126         7.563         8.174        10.192         5.672
# 10313         9.126         7.563         8.174        10.192         5.672
#
#        Sensor_S  Pressure  Object_size  Finger_distance  Trial
# 0        14.974      P0.7            L              cen      1
# 1        14.974      P0.7            L              cen      1
# 2        14.974      P0.7            L              cen      1
# 3        14.974      P0.7            L              cen      1
# 4        14.974      P0.7            L              cen      1
# ...         ...       ...          ...              ...    ...
# 10309    14.974      P0.7            M              cen      1
# 10310    14.974      P0.7            M              cen      1
# 10311    14.974      P0.7            M              cen      1
# 10312    14.974      P0.7            M              cen      1
# 10313    14.974      P0.7            M              cen      1
#
# [10314 rows x 25 columns]

# %%
path='./csv_files'
Desired_param=[[0,1],[0,1],[0],[0]]
A=data_loader(path,Desired_param)
A.file_searching(path)
list_file=A.desired_file_path(Desired_param)
Columns=['Force_X','Force_Y','Force_Z','Torque_X','Torque_Y','Torque_Z',
         'Sensor_P_1_1','Sensor_P_1_2','Sensor_P_2_1','Sensor_P_2_2',
         'Sensor_P_3_1','Sensor_P_3_2','Sensor_P_4_1','Sensor_P_4_2',
         'Sensor_P_5_1','Sensor_P_5_2','Sensor_P_6_1','Sensor_P_6_2',
         'Sensor_P_7_1','Sensor_P_7_2',
         'Sensor_S']
New_Columns=['Pressure','Object_size','Finger_distance','Trial']

print(A.Selected_Param)
print(list_file)
Total_dataset=A.read_Data_pandas(Columns,New_Columns)
Total_dataset.query('Pressure=="P0.7"')
# Out:
# 1st Folder name :  P0.7_L_cen_1
# Contents in the folder : ['ANALOGUE.csv', 'Force.csv', 'TCP.csv']
#
#
# 1 Parameters ['P0.7' 'P1.4' 'P2.1']
#
# 2 Parameters ['L' 'M' 's']
#
# 3 Parameters ['cen']
#
# 4 Parameters ['1' '2' '3']
#
# [['P0.7', 'L', 'cen', '1'], ['P0.7', 'M', 'cen', '1'], ['P1.4', 'L', 'cen', '1'], ['P1.4', 'M', 'cen', '1']]
# ['./csv_files/P0.7_L_cen_1', './csv_files/P0.7_M_cen_1', './csv_files/P1.4_L_cen_1', './csv_files/P1.4_M_cen_1']

# %%
Columns=['Force_X','Force_Y','Force_Z','Torque_X','Torque_Y','Torque_Z',
         'Sensor_P_1_1','Sensor_P_1_2','Sensor_P_2_1','Sensor_P_2_2',
         'Sensor_P_3_1','Sensor_P_3_2','Sensor_P_4_1','Sensor_P_4_2',
         'Sensor_P_5_1','Sensor_P_5_2','Sensor_P_6_1','Sensor_P_6_2',
         'Sensor_P_7_1','Sensor_P_7_2',
         'Sensor_S']
Desired_param=[[0],[0],[0],[0,1]]
A=data_loader(path,Desired_param)
# Out:
# ho
#        Force_X   Force_Y   Force_Z  Torque_X  Torque_Y  Torque_Z  \
# 0    -0.001032  0.003147  0.027862  0.000034  0.000008 -0.000392
# 1    -0.001032  0.003147  0.027862  0.000034  0.000008 -0.000392
# 2    -0.001032  0.003147  0.027862  0.000034  0.000008 -0.000392
# 3    -0.001032  0.003147  0.027862  0.000034  0.000008 -0.000392
# 4    -0.001032  0.003147  0.027862  0.000034  0.000008 -0.000392
# ...        ...       ...       ...       ...       ...       ...
# 5152 -0.003196  0.022557  0.039090  0.000388 -0.000059 -0.000344
# 5153 -0.003196  0.022557  0.039090  0.000388 -0.000059 -0.000344
# 5154 -0.003186  0.022070  0.037911  0.000373 -0.000106 -0.000351
# 5155 -0.003186  0.022070  0.037911  0.000373 -0.000106 -0.000351
# 5156 -0.003186  0.022070  0.037911  0.000373 -0.000106 -0.000351
#
#       Sensor_P_1_1  Sensor_P_1_2  Sensor_P_2_1  Sensor_P_2_2  ...  \
# 0              0.0           0.0         3.674         7.520  ...
# 1              0.0           0.0         3.674         7.520  ...
# 2              0.0           0.0         3.674         7.520  ...
# 3              0.0           0.0         3.674         7.520  ...
# 4              0.0           0.0         3.674         7.520  ...
# ...            ...           ...           ...           ...  ...
# 5152           0.0           0.0         3.675         7.521  ...
# 5153           0.0           0.0         3.675         7.521  ...
# 5154           0.0           0.0         3.675         7.521  ...
# 5155           0.0           0.0         3.675         7.521  ...
# 5156           0.0           0.0         3.675         7.521  ...
#
#       Sensor_P_3_2  Sensor_P_4_1  Sensor_P_4_2  Sensor_P_5_1  Sensor_P_5_2  \
# 0            8.360         8.181         8.699         7.640         9.118
# 1            8.360         8.181         8.699         7.645         9.124
# 2            8.360         8.181         8.699         7.645         9.124
# 3            8.360         8.181         8.699         7.645         9.124
# 4            8.360         8.181         8.699         7.645         9.124
# ...            ...           ...           ...           ...           ...
# 5152         8.357         8.184         8.708         7.641         9.126
# 5153         8.357         8.184         8.708         7.641         9.126
# 5154         8.357         8.184         8.708         7.641         9.126
# 5155         8.357         8.184         8.708         7.641         9.126
# 5156         8.357         8.184         8.708         7.641         9.126
#
#       Sensor_P_6_1  Sensor_P_6_2  Sensor_P_7_1  Sensor_P_7_2  Sensor_S
# 0            7.565         8.181        10.200         5.680    14.974
# 1            7.565         8.181        10.200         5.680    14.974
# 2            7.565         8.181        10.200         5.680    14.974
# 3            7.565         8.183        10.198         5.669    14.974
# 4            7.565         8.183        10.198         5.669    14.974
# ...            ...           ...           ...           ...       ...
# 5152         7.563         8.174        10.192         5.672    14.974
# 5153         7.563         8.174        10.192         5.672    14.974
# 5154         7.563         8.174        10.192         5.672    14.974
# 5155         7.563         8.174        10.192         5.672    14.974
# 5156         7.563         8.174        10.192         5.672    14.974
#
# [5157 rows x 21 columns]

# %%
with open('vectorset', 'rb') as f:
    data_set = pickle.load(f)

# %%
data_set
df = pd.DataFrame(data_set, columns=Columns)

# %%
df
# Out:
#        Force_X   Force_Y   Force_Z  Torque_X  Torque_Y  Torque_Z  \
# 0    -0.001032  0.003147  0.027862  0.000034  0.000008 -0.000392
# 1    -0.001032  0.003147  0.027862  0.000034  0.000008 -0.000392
# 2    -0.001032  0.003147  0.027862  0.000034  0.000008 -0.000392
# 3    -0.001032  0.003147  0.027862  0.000034  0.000008 -0.000392
# 4    -0.001032  0.003147  0.027862  0.000034  0.000008 -0.000392
# ...        ...       ...       ...       ...       ...       ...
# 5152 -0.003196  0.022557  0.039090  0.000388 -0.000059 -0.000344
# 5153 -0.003196  0.022557  0.039090  0.000388 -0.000059 -0.000344
# 5154 -0.003186  0.022070  0.037911  0.000373 -0.000106 -0.000351
# 5155 -0.003186  0.022070  0.037911  0.000373 -0.000106 -0.000351
# 5156 -0.003186  0.022070  0.037911  0.000373 -0.000106 -0.000351
#
#       Sensor_P_1_1  Sensor_P_1_2  Sensor_P_2_1  Sensor_P_2_2  ...  \
# 0              0.0           0.0         3.674         7.520  ...
# 1              0.0           0.0         3.674         7.520  ...
# 2              0.0           0.0         3.674         7.520  ...
# 3              0.0           0.0         3.674         7.520  ...
# 4              0.0           0.0         3.674         7.520  ...
# ...            ...           ...           ...           ...  ...
# 5152           0.0           0.0         3.675         7.521  ...
# 5153           0.0           0.0         3.675         7.521  ...
# 5154           0.0           0.0         3.675         7.521  ...
# 5155           0.0           0.0         3.675         7.521  ...
# 5156           0.0           0.0         3.675         7.521  ...
#
#       Sensor_P_3_2  Sensor_P_4_1  Sensor_P_4_2  Sensor_P_5_1  Sensor_P_5_2  \
# 0            8.360         8.181         8.699         7.640         9.118
# 1            8.360         8.181         8.699         7.645         9.124
# 2            8.360         8.181         8.699         7.645         9.124
# 3            8.360         8.181         8.699         7.645         9.124
# 4            8.360         8.181         8.699         7.645         9.124
# ...            ...           ...           ...           ...           ...
# 5152         8.357         8.184         8.708         7.641         9.126
# 5153         8.357         8.184         8.708         7.641         9.126
# 5154         8.357         8.184         8.708         7.641         9.126
# 5155         8.357         8.184         8.708         7.641         9.126
# 5156         8.357         8.184         8.708         7.641         9.126
#
#       Sensor_P_6_1  Sensor_P_6_2  Sensor_P_7_1  Sensor_P_7_2  Sensor_S
# 0            7.565         8.181        10.200         5.680    14.974
# 1            7.565         8.181        10.200         5.680    14.974
# 2            7.565         8.181        10.200         5.680    14.974
# 3            7.565         8.183        10.198         5.669    14.974
# 4            7.565         8.183        10.198         5.669    14.974
# ...            ...           ...           ...           ...       ...
# 5152         7.563         8.174        10.192         5.672    14.974
# 5153         7.563         8.174        10.192         5.672    14.974
# 5154         7.563         8.174        10.192         5.672    14.974
# 5155         7.563         8.174        10.192         5.672    14.974
# 5156         7.563         8.174        10.192         5.672    14.974
#
# [5157 rows x 21 columns]

# %%
path='./csv_files'
Desired_param=[[0],[0],[0],[0,1]]
A=data_loader(path,Desired_param)
A.file_searching(path)
list_file=A.desired_file_path(Desired_param)
print(A.Selected_Param)
print(list_file)
# Out:
# 1st Folder name :  P0.7_L_cen_1
# Contents in the folder : ['ANALOGUE.csv', 'Force.csv', 'TCP.csv']
#
#
# 1 Parameters ['P0.7' 'P1.4' 'P2.1']
#
# 2 Parameters ['L' 'M' 's']
#
# 3 Parameters ['cen']
#
# 4 Parameters ['1' '2' '3']
#
# [['P0.7', 'L', 'cen', '1'], ['P0.7', 'L', 'cen', '2']]
# ['./csv_files/P0.7_L_cen_1', './csv_files/P0.7_L_cen_2']

# %%
A=data_formatter(path,Desired_param)
A.file_searching(path)
A.desired_file_path(Desired_param)
new_list=A.Desired_file_directory
print(new_list)

# %%
A.file_searching(path)
# Out:
# 1st Folder name :  .ipynb_checkpoints
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 A.file_searching(path)
#
# Cell In[2], line 34, in data_formatter.file_searching(self, path)
#      32 k=0
#      33 print("1st Folder name : ", self.file_directory[0])
# ---> 34 self.contents=os.listdir(os.path.join(self.path,file_list))
#      35 print("Contents in the folder :", self.contents,"\n\n")
#      36 for i in range(len(self.Param[1])):
#
# NotADirectoryError: [WinError 267] 디렉터리 이름이 올바르지 않습니다: './vectorset'

# %%
A=data_formatter(path)

# %%
data_formatter(path)

# %%
path='./'

# %%
data_formatter
.file_searching(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 file_searching(path)
#
# NameError: name 'file_searching' is not defined

# %%
A=data_formatter

# %%
A.file_searching(A,path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 A.file_searching(A,path)
#
# Cell In[2], line 24, in data_formatter.file_searching(self, path)
#      20 for file_list in file_lists:
#      21     #print(file_list)
#      22     # Only extract folder
#      23     if os.path.isdir(os.path.join(path,file_list)):
# ---> 24         self.file_directory.append(file_list)
#      26 ## 2. Parameter list
#      27 self.Param=[]
#
# AttributeError: type object 'data_formatter' has no attribute 'file_directory'
