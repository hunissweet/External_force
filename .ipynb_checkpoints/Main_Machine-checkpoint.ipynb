# %% [markdown]
# # 1. Library

# %%
import os
import torch

import pandas as pd
from torch.utils.data.dataset import Dataset,DataLoader
from sklearn.model_selection import train_test_split

import sklearn.preprocessing
#from directory_tree import display_tree
# Customed Library
import engine ,model_builder,utils
import data_loader
import numpy as np
#import torchinfo
from timeit import default_timer as timer 
from ros_data_reader import Vector_set
#display_tree('./')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[33], line 5
#       2 import torch
#       4 import pandas as pd
# ----> 5 from torch.utils.data.dataset import Dataset,DataLoader
#       6 from sklearn.model_selection import train_test_split
#       8 import sklearn.preprocessing
#
# ImportError: cannot import name 'DataLoader' from 'torch.utils.data.dataset' (/home/ipk410/.local/lib/python3.8/site-packages/torch/utils/data/dataset.py)

# %% [markdown]
# # 2. Data loading

# %%
path='./rosbag_dir'
Desired_param=[[0],[0],[0],[0],[0,1,2]]
A=data_loader.data_loader(path,Desired_param)
A.file_searching(path)
list_file=A.desired_file_path(Desired_param)
Columns=['Force_X','Force_Y','Force_Z','Torque_X','Torque_Y','Torque_Z',
         'Sensor_P_1_1','Sensor_P_1_2','Sensor_P_2_1','Sensor_P_2_2',
         'Sensor_P_3_1','Sensor_P_3_2','Sensor_P_4_1','Sensor_P_4_2',
         'Sensor_P_5_1','Sensor_P_5_2','Sensor_P_6_1','Sensor_P_6_2',
         'Sensor_P_7_1','Sensor_P_7_2',
         'Sensor_S']
New_Columns=['Par1','Par2','Par3','Par4','Par5']
Total_dataset=A.read_Data_pandas(Columns,New_Columns)
Total_dataset
# Out:
# 1st Folder name :  test_26_05_23_v3
# Contents in the folder : ['metadata.yaml', 'test_26_05_23_0.db3']
#
#
# 1 Parameters ['test']
#
# 2 Parameters ['26']
#
# 3 Parameters ['05']
#
# 4 Parameters ['23']
#
# 5 Parameters ['v3' 'v2' 'v1']
#         Force_X   Force_Y   Force_Z  Torque_X  Torque_Y  Torque_Z  \
# 0      0.006219  0.080952  0.277508  0.001852 -0.001192 -0.003365
# 1      0.005250  0.079571  0.274930  0.001843 -0.001223 -0.003368
# 2      0.005250  0.079571  0.274930  0.001843 -0.001223 -0.003368
# 3      0.005250  0.079571  0.274930  0.001843 -0.001223 -0.003368
# 4      0.005250  0.079571  0.274930  0.001843 -0.001223 -0.003368
# ...         ...       ...       ...       ...       ...       ...
# 22827 -0.003196  0.022557  0.039090  0.000388 -0.000059 -0.000344
# 22828 -0.003196  0.022557  0.039090  0.000388 -0.000059 -0.000344
# 22829 -0.003186  0.022070  0.037911  0.000373 -0.000106 -0.000351
# 22830 -0.003186  0.022070  0.037911  0.000373 -0.000106 -0.000351
# 22831 -0.003186  0.022070  0.037911  0.000373 -0.000106 -0.000351
#
#        Sensor_P_1_1  Sensor_P_1_2  Sensor_P_2_1  Sensor_P_2_2  ...  \
# 0               0.0           0.0         3.735         8.679  ...
# 1               0.0           0.0         3.735         8.679  ...
# 2               0.0           0.0         3.735         8.679  ...
# 3               0.0           0.0         3.735         8.679  ...
# 4               0.0           0.0         3.735         8.679  ...
# ...             ...           ...           ...           ...  ...
# 22827           0.0           0.0         3.675         7.521  ...
# 22828           0.0           0.0         3.675         7.521  ...
# 22829           0.0           0.0         3.675         7.521  ...
# 22830           0.0           0.0         3.675         7.521  ...
# 22831           0.0           0.0         3.675         7.521  ...
#
#        Sensor_P_6_1  Sensor_P_6_2  Sensor_P_7_1  Sensor_P_7_2  Sensor_S  Par1  \
# 0             7.538         8.170        10.205         6.274    14.974  test
# 1             7.538         8.170        10.205         6.274    14.974  test
# 2             7.538         8.170        10.204         6.250    14.974  test
# 3             7.538         8.170        10.204         6.250    14.974  test
# 4             7.538         8.170        10.204         6.250    14.974  test
# ...             ...           ...           ...           ...       ...   ...
# 22827         7.563         8.174        10.192         5.672    14.974  test
# 22828         7.563         8.174        10.192         5.672    14.974  test
# 22829         7.563         8.174        10.192         5.672    14.974  test
# 22830         7.563         8.174        10.192         5.672    14.974  test
# 22831         7.563         8.174        10.192         5.672    14.974  test
#
#        Par2  Par3  Par4  Par5
# 0        26    05    23    v3
# 1        26    05    23    v3
# 2        26    05    23    v3
# 3        26    05    23    v3
# 4        26    05    23    v3
# ...     ...   ...   ...   ...
# 22827    26    05    23    v1
# 22828    26    05    23    v1
# 22829    26    05    23    v1
# 22830    26    05    23    v1
# 22831    26    05    23    v1
#
# [22832 rows x 26 columns]

# %% [markdown]
# ### 3-1. FIltering

# %%
## Data filtering
# https://builtin.com/data-science/pandas-filter
Filtered_dataset=Total_dataset.query('Par5=="v1" and Force_X>0')
Filtered_dataset
# Out:
#         Force_X   Force_Y   Force_Z  Torque_X  Torque_Y  Torque_Z  \
# 17690  0.000827  0.003789  0.026325  0.000052 -0.000083 -0.000425
# 17691  0.000827  0.003789  0.026325  0.000052 -0.000083 -0.000425
# 17692  0.000827  0.003789  0.026325  0.000052 -0.000083 -0.000425
# 17693  0.000827  0.003789  0.026325  0.000052 -0.000083 -0.000425
# 17694  0.000827  0.003789  0.026325  0.000052 -0.000083 -0.000425
# ...         ...       ...       ...       ...       ...       ...
# 20835  0.000048  0.017580  0.035686  0.000342 -0.000061 -0.000371
# 20836  0.000048  0.017580  0.035686  0.000342 -0.000061 -0.000371
# 20837  0.000048  0.017580  0.035686  0.000342 -0.000061 -0.000371
# 20838  0.000048  0.017580  0.035686  0.000342 -0.000061 -0.000371
# 20839  0.000048  0.017580  0.035686  0.000342 -0.000061 -0.000371
#
#        Sensor_P_1_1  Sensor_P_1_2  Sensor_P_2_1  Sensor_P_2_2  ...  \
# 17690          0.00          0.00         3.675         7.516  ...
# 17691          0.00          0.00         3.675         7.516  ...
# 17692          0.00          0.00         3.675         7.516  ...
# 17693          0.00          0.00         3.675         7.516  ...
# 17694          0.00          0.00         3.675         7.516  ...
# ...             ...           ...           ...           ...  ...
# 20835          0.29          1.56         3.675         7.521  ...
# 20836          0.29          2.23         3.675         7.521  ...
# 20837          0.29          2.23         3.675         7.521  ...
# 20838          0.29          2.23         3.675         7.521  ...
# 20839          0.29          2.23         3.675         7.521  ...
#
#        Sensor_P_6_1  Sensor_P_6_2  Sensor_P_7_1  Sensor_P_7_2  Sensor_S  Par1  \
# 17690         7.565         8.179        10.208         5.681    14.974  test
# 17691         7.565         8.179        10.208         5.681    14.974  test
# 17692         7.565         8.179        10.208         5.681    14.974  test
# 17693         7.565         8.179        10.208         5.681    14.974  test
# 17694         7.565         8.179        10.208         5.681    14.974  test
# ...             ...           ...           ...           ...       ...   ...
# 20835         7.563         8.174        10.192         5.672    14.974  test
# 20836         7.563         8.174        10.192         5.672    14.974  test
# 20837         7.563         8.174        10.192         5.672    14.974  test
# 20838         7.563         8.174        10.192         5.672    14.974  test
# 20839         7.563         8.174        10.192         5.672    14.974  test
#
#        Par2  Par3  Par4  Par5
# 17690    26    05    23    v1
# 17691    26    05    23    v1
# 17692    26    05    23    v1
# 17693    26    05    23    v1
# 17694    26    05    23    v1
# ...     ...   ...   ...   ...
# 20835    26    05    23    v1
# 20836    26    05    23    v1
# 20837    26    05    23    v1
# 20838    26    05    23    v1
# 20839    26    05    23    v1
#
# [911 rows x 26 columns]

# %% [markdown]
# ### 3-2 Combination of the data

# %%
Total_col=[*Columns,*New_Columns]
for i in range(len(Total_col)):
    if i==0:
        print(f'{"Total column" :^120}')
        print('')
    print(f'{i:<} {Total_col[i] : <30}   ',end='')
    if i%3 ==0 and i!=0:
        print('')
        

Desired_combination_COL=[*Total_col[0:3],*Total_col[-9:-5]] ####################### chose the combination of the col
print('')
for i in range(len(Desired_combination_COL)):
    if i==0:
        print(f'{"Desired_combination_COL" :^120}')
        print('')
    print(f'{i:<} {Desired_combination_COL[i] : <30}   ',end='')
    if i%3 ==0 and i!=0:
        print('')


Desired_combination_COL
Combi_df=Filtered_dataset.filter(items=Desired_combination_COL)
# Out:
#                                                       Total column
#
# 0 Force_X                          1 Force_Y                          2 Force_Z                          3 Torque_X
# 4 Torque_Y                         5 Torque_Z                         6 Sensor_P_1_1
# 7 Sensor_P_1_2                     8 Sensor_P_2_1                     9 Sensor_P_2_2
# 10 Sensor_P_3_1                     11 Sensor_P_3_2                     12 Sensor_P_4_1
# 13 Sensor_P_4_2                     14 Sensor_P_5_1                     15 Sensor_P_5_2
# 16 Sensor_P_6_1                     17 Sensor_P_6_2                     18 Sensor_P_7_1
# 19 Sensor_P_7_2                     20 Sensor_S                         21 Par1
# 22 Par2                             23 Par3                             24 Par4
# 25 Par5
#                                                 Desired_combination_COL
#
# 0 Force_X                          1 Force_Y                          2 Force_Z                          3 Sensor_P_6_2
# 4 Sensor_P_7_1                     5 Sensor_P_7_2                     6 Sensor_S

# %% [markdown]
# ### 3. Save the file into pickle format

# %%
save_mode= True

if save_mode== True:
    Combi_df.to_pickle("./pickle/test_1.pkl")

# %% [markdown]
# # 3.Start

# %% [markdown]
# ### 3-1. Data loading and preparation
# 1) Read pickle
# 2) Divide Input and output && Train and test set
# 3) To Tensor
# 4) Normalization
# 5) Batch size

# %%
Combi_df = pd.read_pickle("./pickle/test_1.pkl")  
# Hot encoding needed
# Scailing!
# Validation dataset?

Y=np.array(Combi_df.filter(items=Desired_combination_COL[0:3]))
X=np.array(Combi_df.filter(items=Desired_combination_COL[3:]))

# Scaler
X_scaler = sklearn.preprocessing.MinMaxScaler()
Y_scaler = sklearn.preprocessing.MinMaxScaler()

X=torch.FloatTensor(X_scaler.fit_transform(X))
Y=torch.FloatTensor(Y_scaler.fit_transform(Y))



X_train, X_test, Y_train, Y_test = train_test_split(X, 
                                                    Y, 
                                                    test_size=0.2, # 20% test, 80% train
                                                    random_state=42) # make the random split reproducible


train_dataset=DataLoader(data_loader.Data(X_train,Y_train))
test_dataset=DataLoader(data_loader.Data(X_test,Y_test))
Input_dim=len(X_train[0])
Output_dim=len(Y_train[0])

print(f'{"Input dim ":>20}{Input_dim}{"||":^22}{"Output dim ":>20}{Output_dim}')
print(f'Input Train: {len(X_train)},Test: {len(X_test)}   ||   Output Train: {len(Y_train)}, Test: {len(Y_test)}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 24
#      14 Y=torch.FloatTensor(Y_scaler.fit_transform(Y))
#      18 X_train, X_test, Y_train, Y_test = train_test_split(X,
#      19                                                     Y,
#      20                                                     test_size=0.2, # 20% test, 80% train
#      21                                                     random_state=42) # make the random split reproducible
# ---> 24 train_dataset=DataLoader(data_loader.Data(X_train,Y_train))
#      25 test_dataset=DataLoader(data_loader.Data(X_test,Y_test))
#      26 Input_dim=len(X_train[0])
#
# NameError: name 'DataLoader' is not defined

# %% [markdown]
# ### 3-2. Set hypermeter
# 1. Epochs
# 2. Batch size
# 3. Learning rate
# 4. Device
# 5. Activation function
# 6. Loss function
# 7. Optimizer

# %%
# Setup hyperparameters
NUM_EPOCHS = 5
BATCH_SIZE = 32
HIDDEN_UNITS = 10
LEARNING_RATE = 0.001
device = "cuda" if torch.cuda.is_available() else "cpu"


# Model

model = model_builder.LSTMModel(
    input_dim = Input_dim,
    hidden_dim=HIDDEN_UNITS,
    layer_dim=2,
    output_dim=Output_dim,
    dropout_prob=0.7)


# Set loss and optimizer
loss_fn = torch.nn.MSELoss() ## change
optimizer = torch.optim.Adam(model.parameters(), ## change
                             lr=LEARNING_RATE)

# %% [markdown]
# ### 3-3. Model

# %%
train_dataset

# %%
#torchinfo.summary(model,(5,5,5))
start_time = timer()
results=engine.train(model=model,
             train_dataloader=train_dataset,
             test_dataloader=test_dataset,
             loss_fn=loss_fn,
             optimizer=optimizer,
             epochs=NUM_EPOCHS,
             device=device)
end_time = timer()
print(f"Total training time: {end_time-start_time:.3f} seconds")
utils.plot_loss_curves(results)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[29], line 3
#       1 #torchinfo.summary(model,(5,5,5))
#       2 start_time = timer()
# ----> 3 results=engine.train(model=model,
#       4              train_dataloader=train_dataset,
#       5              test_dataloader=test_dataset,
#       6              loss_fn=loss_fn,
#       7              optimizer=optimizer,
#       8              epochs=NUM_EPOCHS,
#       9              device=device)
#      10 end_time = timer()
#      11 print(f"Total training time: {end_time-start_time:.3f} seconds")
#
# File ~/janghun/External_force-main/engine.py:163, in train(model, train_dataloader, test_dataloader, optimizer, loss_fn, epochs, device)
#     161 # Loop through training and testing steps for a number of epochs
#     162 for epoch in tqdm(range(epochs)):
# --> 163     train_loss, train_acc = train_step(model=model,
#     164                                       dataloader=train_dataloader,
#     165                                       loss_fn=loss_fn,
#     166                                       optimizer=optimizer,
#     167                                       device=device)
#     168     test_loss, test_acc = test_step(model=model,
#     169       dataloader=test_dataloader,
#     170       loss_fn=loss_fn,
#     171       device=device)
#     173   # Print out what's happening
#
# File ~/janghun/External_force-main/engine.py:42, in train_step(model, dataloader, loss_fn, optimizer, device)
#      39 X, y = X.to(device), y.to(device)
#      41 # 1. Forward pass
# ---> 42 y_pred = model(X)
#      44 # 2. Calculate  and accumulate loss
#      45 loss = loss_fn(y_pred, y)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/janghun/External_force-main/model_builder.py:29, in LSTMModel.forward(self, x)
#      24 c0 = torch.zeros(self.layer_dim, x.size(0), self.hidden_dim).requires_grad_()
#      26 # We need to detach as we are doing truncated backpropagation through time (BPTT)
#      27 # If we don't, we'll backprop all the way to the start even after going through another batch
#      28 # Forward propagation by passing in the input, hidden state, and cell state into the model
# ---> 29 out, (hn, cn) = self.lstm(x, (h0.detach(), c0.detach()))
#      31 # Reshaping the outputs in the shape of (batch_size, seq_length, hidden_size)
#      32 # so that it can fit into the fully connected layer
#      33 out = out[:, -1, :]
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/rnn.py:773, in LSTM.forward(self, input, hx)
#     771 else:
#     772     batch_sizes = None
# --> 773     assert (input.dim() in (2, 3)), f"LSTM: Expected input to be 2-D or 3-D but received {input.dim()}-D tensor"
#     774     is_batched = input.dim() == 3
#     775     batch_dim = 0 if self.batch_first else 1
#
# AssertionError: LSTM: Expected input to be 2-D or 3-D but received 1-D tensor

# %% [markdown]
# ### 3-4 Compare the results and save
