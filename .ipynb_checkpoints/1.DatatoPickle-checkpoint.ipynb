# %% [markdown]
# # 1. Library

# %%
import os
import torch

import pandas as pd
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split

import sklearn.preprocessing
#from directory_tree import display_tree
# Customed Library
import engine ,model_builder,utils
import data_loader
import numpy as np
#import torchinfo
from timeit import default_timer as timer 
from ros_data_reader import Vector_set,Est_set
#display_tree('./')
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# # 2. Data loading
#
# ROS bag data formater => Pickle

# %%
#path='./rosbag_dir'
#Desired_param=[[0],[0],[0],[0],[0,1,2]]
#New_Columns=['Par1','Par2','Par3','Par4','Par5']



#####################################
# Walk through the folder. Make a list with '_'. You can chose the specific parameter########3
# ex) file_name : pressure_1,Bigobject_3 => make a list : [pressure, Bigobject], [1,3] 
# ex) input [[0],[0]] => pressure_1

path='./rosbag_dir/data/dec_13' # address of rosbag folder
Desired_param=[[3],[0,1,2,3]] # choose specific parameters
New_Columns=['shape','Properties'] # nameing each parameters
#####################################

A=data_loader.data_loader(path,Desired_param)
A.file_searching(path)
list_file=A.desired_file_path(Desired_param)
Columns=['Flag',
         'Force_X','Force_Y','Force_Z','Torque_X','Torque_Y','Torque_Z',
         'Input_P_1','Input_P_2',
         'TCP_X','TCP_Y','TCP_Z',
         'Sensor_P_1_1','Sensor_P_1_2','Sensor_P_1_3','Sensor_P_1_4',
         'Sensor_P_1_5','Sensor_P_1_6','Sensor_P_1_7','Sensor_P_1_8',
         'Sensor_P_1_9','Sensor_P_1_10','Sensor_P_1_11','Sensor_P_1_12',
         'Sensor_S_1',
         'Sensor_P_2_1','Sensor_P_2_2','Sensor_P_2_3','Sensor_P_2_4',
         'Sensor_P_2_5','Sensor_P_2_6','Sensor_P_2_7','Sensor_P_2_8',
         'Sensor_P_2_9','Sensor_P_2_10','Sensor_P_2_11','Sensor_P_2_12',
         'Sensor_S_2'
        ]

Total_dataset=A.read_Data_pandas(Columns,New_Columns)
Total_dataset

pickle_address ="./pickle/dec_13/nonc.pkl" # change the pickle address
Total_dataset.to_pickle(pickle_address)
# Out:
# 1st Folder name :  cirr_2
# Contents in the folder : ['metadata.yaml', 'cv_4_0.db3']
#
#
# 1 Parameters ['cirr' 'cvv' 'sqq' 'noc']
#
# 2 Parameters ['2' '3' '1' '4']
#          Flag   Force_X   Force_Y   Force_Z  Torque_X  Torque_Y  Torque_Z  \
# 0       False  0.148358 -0.226280  0.082129 -0.017629 -0.004360 -0.001640
# 1       False  0.148358 -0.226280  0.082129 -0.017629 -0.004360 -0.001640
# 2       False  0.148358 -0.226280  0.082129 -0.017629 -0.004360 -0.001640
# 3       False  0.148175 -0.224398  0.084108 -0.017652 -0.004366 -0.001583
# 4       False  0.148175 -0.224398  0.084108 -0.017652 -0.004366 -0.001583
# ...       ...       ...       ...       ...       ...       ...       ...
# 133545  False  0.150058 -0.227475  0.062263 -0.017672 -0.004336 -0.001616
# 133546  False  0.150058 -0.227475  0.062263 -0.017672 -0.004336 -0.001616
# 133547  False  0.150058 -0.227475  0.062263 -0.017672 -0.004336 -0.001616
# 133548  False  0.150058 -0.227475  0.062263 -0.017672 -0.004336 -0.001616
# 133549  False  0.150058 -0.227475  0.062263 -0.017672 -0.004336 -0.001616
#
#         Input_P_1  Input_P_2     TCP_X  ...  Sensor_P_2_6  Sensor_P_2_7  \
# 0             0.0        0.0 -0.033878  ...    443.699982    453.399994
# 1             0.0        0.0 -0.033878  ...    443.699982    453.399994
# 2             0.0        0.0 -0.033878  ...    443.699982    453.399994
# 3             0.0        0.0 -0.033878  ...    443.699982    453.399994
# 4             0.0        0.0 -0.033878  ...    443.699982    453.399994
# ...           ...        ...       ...  ...           ...           ...
# 133545        0.0        0.0 -0.033635  ...    438.100006    450.600006
# 133546        0.0        0.0 -0.033635  ...    438.100006    450.600006
# 133547        0.0        0.0 -0.033635  ...    438.100006    450.600006
# 133548        0.0        0.0 -0.033623  ...    438.100006    450.600006
# 133549        0.0        0.0 -0.033623  ...    438.100006    450.600006
#
#         Sensor_P_2_8  Sensor_P_2_9  Sensor_P_2_10  Sensor_P_2_11  \
# 0         468.300018    506.600006     423.999969     417.000000
# 1         468.300018    506.600006     423.999969     417.000000
# 2         468.300018    506.600006     423.999969     417.000000
# 3         468.300018    506.600006     423.999969     417.000000
# 4         468.300018    506.600006     423.999969     417.000000
# ...              ...           ...            ...            ...
# 133545    467.700012    498.799988     423.199982     412.799988
# 133546    467.700012    498.799988     423.199982     412.799988
# 133547    467.700012    498.799988     423.199982     412.799988
# 133548    467.700012    498.799988     423.199982     412.799988
# 133549    467.700012    498.799988     423.199982     412.799988
#
#         Sensor_P_2_12  Sensor_S_2  shape  Properties
# 0          753.299988       279.0    noc           3
# 1          754.700012       282.0    noc           3
# 2          754.700012       282.0    noc           3
# 3          754.700012       282.0    noc           3
# 4          754.700012       282.0    noc           3
# ...               ...         ...    ...         ...
# 133545     666.699951       279.0    noc           2
# 133546     666.699951       279.0    noc           2
# 133547     666.699951       279.0    noc           2
# 133548     666.699951       279.0    noc           2
# 133549     666.699951       279.0    noc           2
#
# [133550 rows x 40 columns]
